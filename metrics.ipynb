# %%
from matplotlib import pyplot as plt
import pandas as pd
plots = [
    pd.read_csv("topo_minimal.csv"),
    pd.read_csv("topo_single4.csv"),
    pd.read_csv("topo_linear4.csv"),
    pd.read_csv("topo_reversed4.csv"),
    pd.read_csv("topo_tree4.csv"),
]
title = [
    "Minimal",
    "Single N = 4",
    "Linear N = 4",
    "Reversed N = 4",
    "Tree N = 4"
]
data = []
for i in range(len(plots)):
    data.append((
        plots[i]["Timestamp"],
        plots[i]['Uso de memória (MiB)'],
        plots[i]['% de uso de CPU']
    ))


colors = [
    'tab:red',
    'tab:blue'
]


# Plot Line1 (Left Y Axis)
fig, ax = plt.subplots(len(plots),2, dpi= 200)
for i in range(len(plots)):
    ax[i, 0].plot(data[i][0], data[i][1], linewidth=4, color=colors[0])
    ax[i, 1].plot(data[i][0], data[i][2], linewidth=4, color=colors[1])

    if(i == 0):
        ax[i, 0].set_title('Uso de memória (Max 300 MiB)', pad=10, color=colors[0])
    ax[i, 0].set_ylabel(title[i], labelpad =40, rotation=0, color="black")
    ax[i, 0].tick_params(axis='y', labelcolor=colors[0], labelsize=7 )
    ax[i, 0].tick_params(left = True, right = False , labelleft = True , labelbottom = True, bottom = True)
    ax[i, 0].tick_params(axis='x', rotation=25, labelsize=8)
    # ax[0].set_xlabel('Tempo', fontsize=20)

    if(i == 0):
        ax[i, 1].set_title('Uso de CPU (Max 400)', pad=10, color=colors[1])
    # ax[i, 1].set_ylabel("%", labelpad =20, rotation=0, color=colors[1],)
    ax[i, 1].tick_params(axis='y', labelcolor=colors[1], labelsize=7 )
    ax[i, 1].tick_params(axis='x', rotation=25, labelsize=8)

    # ax[1].set_xlabel('Tempo', fontsize=20)

    for j in range(2):
        # ax[i, j].axvline(x="19:18:26", linewidth=2.5, color='purple', linestyle=':', label='Execução da Topologia')
        # ax[i, j].axvline(x="19:18:40", linewidth=2.5, color='blue',  linestyle='-.', label='Execução do pingall')
        ax[i, j].grid(alpha=.4)
        every_nth = 4
        for n, label in enumerate(ax[i, j].xaxis.get_ticklabels()):
            if n % every_nth != 0:
                label.set_visible(False)



# Hide x labels and tick labels for top plots and y ticks for right plots.
# for x in ax.flat:
#     x.label_outer()

for x in range(len(plots)):
    # x.set(xlabel='x-label', ylabel='y-label')
    plt.setp(ax[x,0].get_xticklabels(), visible=False)
    plt.setp(ax[x,1].get_xticklabels(), visible=False)

plt.locator_params(axis='x', nbins=2)
plt.subplots_adjust(bottom=0.1, hspace=0.2)
fig.tight_layout()
fig.savefig("plots/line_comparisson.png")
plt.legend()
plt.show()
# Out:
# C:\Users\llcos\AppData\Local\Temp\ipykernel_38916\1976480270.py:74: UserWarning: 'set_params()' not defined for locator of type <class 'matplotlib.category.StrCategoryLocator'>
#   plt.locator_params(axis='x', nbins=2)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
 
import pandas as pd
memoryStr = 'Uso de memória (MiB)'
cpuStr = '% de uso de CPU'

title = [
    "Minimal",
    "Single N = 4",
    "Linear N = 4",
    "Reversed N = 4",
    "Tree N = 4"
]
minimal = pd.read_csv("topo_minimal.csv")
single4 = pd.read_csv("topo_single4.csv")
linear4 = pd.read_csv("topo_linear4.csv")
reversed4 = pd.read_csv("topo_reversed4.csv")
tree4 =  pd.read_csv("topo_tree4.csv")

data = [[
  minimal[memoryStr], 
  single4[memoryStr], 
  linear4[memoryStr], 
  reversed4[memoryStr],
  tree4[memoryStr]
],
[
  minimal[cpuStr], 
  single4[cpuStr], 
  linear4[cpuStr], 
  reversed4[cpuStr],
  tree4[cpuStr]
]]
fig, ax = plt.subplots(2, figsize=(16,9), dpi= 200)
fig = plt.figure()
 
for i in range(2):
  bp = ax[i].boxplot(data[i])

ax[0].set_ylabel("Memória",  labelpad =40, rotation=0, color="black")
ax[1].set_ylabel("CPU", labelpad =40, rotation=0, color="black")
for ax_ in ax:
  ax_.set_xticks([1, 2, 3, 4,5], ['Minimal', 'Single 4', 'Linear 4', 'Reversed 4', 'Tree 4'])

fig.savefig("plots/boxplot_comparisson.png")
plt.show()

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
 
import pandas as pd

a = "Uso de memória (MiB)"
b = "Uso de memória"

title = [
  "Users = 2",
  "Users = 4",
  "Users = 6",
  "Users = 8",
  "Users = 10",
  "Users = 12"
]

data = [[
  pd.read_csv("user_2_tree_4_containers.csv")[a], 
  pd.read_csv("user_4_tree_4_containers.csv")[a], 
  pd.read_csv("user_6_tree_4_containers.csv")[a], 
  pd.read_csv("user_8_tree_4_containers.csv")[a], 
  pd.read_csv("user_10_tree_4_containers.csv")[a], 
  pd.read_csv("user_12_tree_4_containers.csv")[a], 
],
[
  pd.read_csv("user_2_tree_4_main.csv")[b], 
  pd.read_csv("user_4_tree_4_main.csv")[b], 
  pd.read_csv("user_6_tree_4_main.csv")[b], 
  pd.read_csv("user_8_tree_4_main.csv")[b], 
  pd.read_csv("user_10_tree_4_main.csv")[b], 
  pd.read_csv("user_12_tree_4_main.csv")[b], 
]]
fig, ax = plt.subplots(2, figsize=(16,9), dpi= 200)
fig = plt.figure()
 
for i in range(2):
  bp = ax[i].boxplot(data[i])
ax[0].set_title('Uso de memória dos containers', pad=10, fontsize=20)
ax[0].set_ylabel("MiB",  labelpad =40, rotation=0, color="black")

ax[1].set_title('Uso de memória da aplicação', pad=10, fontsize=20)
ax[1].set_ylabel("Mb", labelpad =40, rotation=0, color="black")
for ax_ in ax:
  ax_.set_xticks([1, 2, 3, 4, 5, 6], ['2', '4', '6', '8', '10', '12'])

# ax[1].set_xlabel('Quantidade de usuários', fontsize=20)

fig.savefig("plots/boxplot_tree4_users_comparisson.png")
plt.show()

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
 
import pandas as pd

a = "Uso de memória (MiB)"
b = "Uso de memória"

title = [
  "Users = 2",
  "Users = 4",
  "Users = 6",
  "Users = 8",
  "Users = 10",
  "Users = 12"
]

data = [[
  pd.read_csv("user_2_tree_4_containers.csv")[a], 
  pd.read_csv("user_4_tree_4_containers.csv")[a], 
  pd.read_csv("user_6_tree_4_containers.csv")[a], 
  pd.read_csv("user_8_tree_4_containers.csv")[a], 
  pd.read_csv("user_10_tree_4_containers.csv")[a], 
  pd.read_csv("user_12_tree_4_containers.csv")[a], 
],
[
  pd.read_csv("user_2_tree_4_main.csv")[b], 
  pd.read_csv("user_4_tree_4_main.csv")[b], 
  pd.read_csv("user_6_tree_4_main.csv")[b], 
  pd.read_csv("user_8_tree_4_main.csv")[b], 
  pd.read_csv("user_10_tree_4_main.csv")[b], 
  pd.read_csv("user_12_tree_4_main.csv")[b], 
]]
fig, ax = plt.subplots(2, figsize=(16,9), dpi= 200)
fig = plt.figure()
 
for i in range(2):
  bp = ax[i].violinplot(data[i], showmedians = True)
ax[0].set_title('Uso de memória dos containers', pad=10, fontsize=20)
ax[0].set_ylabel("MiB",  labelpad =40, rotation=0, color="black")

ax[1].set_title('Uso de memória da aplicação', pad=10, fontsize=20)
ax[1].set_ylabel("Mb", labelpad =40, rotation=0, color="black")
for ax_ in ax:
  ax_.set_xticks([1, 2, 3, 4, 5, 6], ['2', '4', '6', '8', '10', '12'])
  ax_.grid(alpha=.7)
# ax[1].set_xlabel('Quantidade de usuários', fontsize=20)

fig.savefig("plots/boxplot_tree4_users_comparisson.png")
plt.show()

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
 
# --- FORMAT 1
 
# Your x and y axis
data = [[
  pd.read_csv("user_2_tree_4_containers.csv")[a].median(axis = 0), 
  pd.read_csv("user_4_tree_4_containers.csv")[a].median(axis = 0), 
  pd.read_csv("user_6_tree_4_containers.csv")[a].median(axis = 0), 
  pd.read_csv("user_8_tree_4_containers.csv")[a].median(axis = 0), 
  pd.read_csv("user_10_tree_4_containers.csv")[a].median(axis = 0), 
  pd.read_csv("user_12_tree_4_containers.csv")[a].median(axis = 0), 
],
[
  pd.read_csv("user_2_tree_4_main.csv")[b].median(axis = 0), 
  pd.read_csv("user_4_tree_4_main.csv")[b].median(axis = 0), 
  pd.read_csv("user_6_tree_4_main.csv")[b].median(axis = 0), 
  pd.read_csv("user_8_tree_4_main.csv")[b].median(axis = 0), 
  pd.read_csv("user_10_tree_4_main.csv")[b].median(axis = 0), 
  pd.read_csv("user_12_tree_4_main.csv")[b].median(axis = 0), 
]]
 
print(data)
x = range(0,6)


# Plot Line1 (Left Y Axis)
fig, ax1 = plt.subplots(1,1,figsize=(16,9), dpi= 80)
ax1.plot(x, data[0], color='tab:red')

# Plot Line2 (Right Y Axis)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.plot(x, data[1], color='tab:blue')

# Decorations
# ax1 (left Y axis)
ax1.set_xlabel('Year', fontsize=20)
ax1.tick_params(axis='x', rotation=0, labelsize=12)
ax1.set_ylabel('Personal Savings Rate', color='tab:red', fontsize=20)
ax1.tick_params(axis='y', rotation=0, labelcolor='tab:red' )
ax1.grid(alpha=.4)

# ax2 (right Y axis)
ax2.set_ylabel("# Unemployed (1000's)", color='tab:blue', fontsize=20)
ax2.tick_params(axis='y', labelcolor='tab:blue')
ax2.set_xticks(np.arange(0, len(x), 60))
ax2.set_xticklabels(x[::60], rotation=90, fontdict={'fontsize':10})
ax2.set_title("Personal Savings Rate vs Unemployed: Plotting in Secondary Y Axis", fontsize=22)
fig.tight_layout()
plt.show()
# Out:
# [[122.685, 244.54000000000002, 367.52, 428.78, 550.585, 737.735], [36.623, 37.576, 37.597, 38.712, 40.1325, 40.778499999999994]]

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
 
import pandas as pd

a = "Uso de memória (MiB)"
b = "Uso de memória"

title = [
  "Users = 2",
  "Users = 4",
  "Users = 6",
  "Users = 8",
  "Users = 10",
  "Users = 12"
]

data = [[
  pd.read_csv("user_2_tree_4_containers.csv")[a], 
  pd.read_csv("user_4_tree_4_containers.csv")[a], 
  pd.read_csv("user_6_tree_4_containers.csv")[a], 
  pd.read_csv("user_8_tree_4_containers.csv")[a], 
  pd.read_csv("user_10_tree_4_containers.csv")[a], 
  pd.read_csv("user_12_tree_4_containers.csv")[a], 
],
[
  pd.read_csv("user_2_tree_4_main.csv")[b], 
  pd.read_csv("user_4_tree_4_main.csv")[b], 
  pd.read_csv("user_6_tree_4_main.csv")[b], 
  pd.read_csv("user_8_tree_4_main.csv")[b], 
  pd.read_csv("user_10_tree_4_main.csv")[b], 
  pd.read_csv("user_12_tree_4_main.csv")[b], 
]]
fig, ax = plt.subplots(2, figsize=(16,9), dpi= 200)
fig = plt.figure()
 
for i in range(2):
  bp = ax[i].boxplot(data[i])
ax[0].set_title('Uso de memória dos containers', pad=10, fontsize=20)
ax[0].set_ylabel("MiB",  labelpad =40, rotation=0, color="black")

ax[1].set_title('Uso de memória da aplicação', pad=10, fontsize=20)
ax[1].set_ylabel("Mb", labelpad =40, rotation=0, color="black")
for ax_ in ax:
  ax_.set_xticks([1, 2, 3, 4, 5, 6], ['2', '4', '6', '8', '10', '12'])

ax[1].set_xlabel('Quantidade de usuários', fontsize=20)

fig.savefig("plots/boxplot_tree4_users_comparisson.png")
plt.show()

# %% [markdown]
# # Topologia arvore altura 4
# ## Comando mn --topo tree4

# %%
from matplotlib import pyplot as plt
import pandas as pd
topo = "tree4"
df = pd.read_csv("topo_" + topo + ".csv")

x = df["Timestamp"]
y1 = df['Uso de memória (MiB)']
y2 = df['% de uso de CPU']

colors = [
    'tab:red',
    'tab:blue'
]

# Plot Line1 (Left Y Axis)
fig, ax = plt.subplots(2, figsize=(16,9), dpi= 200)
ax[0].plot(x, y1, linewidth=4, color=colors[0])
ax[1].plot(x, y2, linewidth=4, color=colors[1])


ax[0].set_title('Uso de memória (Max 300 MiB)', pad=10, fontsize=20)
ax[0].set_ylabel("MiB", labelpad =40, rotation=0, color=colors[0], fontsize=20)
ax[0].tick_params(axis='y', labelcolor=colors[0], labelsize=20 )
ax[0].tick_params(left = True, right = False , labelleft = True , labelbottom = False, bottom = False)


ax[1].set_title('Uso de CPU (Max 400%)', pad=10, fontsize=20)
ax[1].set_ylabel("%", labelpad =40, rotation=0, color=colors[1], fontsize=20)
ax[1].tick_params(axis='y', labelcolor=colors[1], labelsize=20 )
ax[1].tick_params(axis='x', rotation=25, labelsize=12)

ax[1].set_xlabel('Tempo', fontsize=20)

for i in range(2):
    ax[i].axvline(x="19:18:26", linewidth=2.5, color='purple', linestyle=':', label='Execução da Topologia')
    ax[i].axvline(x="19:18:40", linewidth=2.5, color='blue',  linestyle='-.', label='Execução do pingall')
    ax[i].grid(alpha=.4)

plt.subplots_adjust(bottom=0.1, hspace=0.2)
fig.tight_layout()
fig.savefig("plots/" + topo + ".png")
plt.legend()
plt.show()

# %% [markdown]
# # Topologia single 2
# ## Comando mn --topo single2

# %%
from matplotlib import pyplot as plt
import pandas as pd

topo = "single2"
df = pd.read_csv("topo_" + topo + ".csv")

x = df["Timestamp"]
y1 = df['Uso de memória (MiB)']
y2 = df['% de uso de CPU']

colors = [
    'tab:red',
    'tab:blue'
]

# Plot Line1 (Left Y Axis)
fig, ax = plt.subplots(2, figsize=(16,9), dpi= 200)
ax[0].plot(x, y1, linewidth=4, color=colors[0])
ax[1].plot(x, y2, linewidth=4, color=colors[1])


ax[0].set_title('Uso de memória (Max 300 MiB)', pad=10, fontsize=20)
ax[0].set_ylabel("MiB", labelpad =40, rotation=0, color=colors[0], fontsize=20)
ax[0].tick_params(axis='y', labelcolor=colors[0], labelsize=20 )
ax[0].tick_params(left = True, right = False , labelleft = True , labelbottom = False, bottom = False)


ax[1].set_title('Uso de CPU (Max 400%)', pad=10, fontsize=20)
ax[1].set_ylabel("%", labelpad =40, rotation=0, color=colors[1], fontsize=20)
ax[1].tick_params(axis='y', labelcolor=colors[1], labelsize=20 )
ax[1].tick_params(axis='x', rotation=25, labelsize=12)

ax[1].set_xlabel('Tempo', fontsize=20)

for i in range(2):
    ax[i].axvline(x="19:15:18", linewidth=2.5, color='purple', linestyle=':', label='Execução da Topologia')
    ax[i].axvline(x="19:15:26", linewidth=2.5, color='blue',  linestyle='-.', label='Execução do pingall')
    ax[i].grid(alpha=.4)

plt.subplots_adjust(bottom=0.1, hspace=0.2)
fig.tight_layout()
fig.savefig("plots/" + topo + ".png")
plt.legend()
plt.show()

# %% [markdown]
# # Topologia single 8
# ## Comando mn --topo single8

# %%
from matplotlib import pyplot as plt
import pandas as pd

topo = "single8"
df = pd.read_csv("topo_" + topo + ".csv")

x = df["Timestamp"]
y1 = df['Uso de memória (MiB)']
y2 = df['% de uso de CPU']

colors = [
    'tab:red',
    'tab:blue'
]

# Plot Line1 (Left Y Axis)
fig, ax = plt.subplots(2, figsize=(16,9), dpi= 200)
ax[0].plot(x, y1, linewidth=4, color=colors[0])
ax[1].plot(x, y2, linewidth=4, color=colors[1])


ax[0].set_title('Uso de memória (Max 300 MiB)', pad=10, fontsize=20)
ax[0].set_ylabel("MiB", labelpad =40, rotation=0, color=colors[0], fontsize=20)
ax[0].tick_params(axis='y', labelcolor=colors[0], labelsize=20 )
ax[0].tick_params(left = True, right = False , labelleft = True , labelbottom = False, bottom = False)


ax[1].set_title('Uso de CPU (Max 400%)', pad=10, fontsize=20)
ax[1].set_ylabel("%", labelpad =40, rotation=0, color=colors[1], fontsize=20)
ax[1].tick_params(axis='y', labelcolor=colors[1], labelsize=20 )
ax[1].tick_params(axis='x', rotation=25, labelsize=12)

ax[1].set_xlabel('Tempo', fontsize=20)

for i in range(2):
    ax[i].axvline(x="19:27:48", linewidth=2.5, color='purple', linestyle=':', label='Execução da Topologia')
    ax[i].axvline(x="19:27:59", linewidth=2.5, color='blue',  linestyle='-.', label='Execução do pingall')
    ax[i].grid(alpha=.4)

plt.subplots_adjust(bottom=0.1, hspace=0.2)
fig.tight_layout()
fig.savefig("plots/" + topo + ".png")
plt.legend()
plt.show()

# %% [markdown]
# # Topologia single 16
# ## Comando mn --topo single16

# %%
from matplotlib import pyplot as plt
import pandas as pd

topo = "single16"
df = pd.read_csv("topo_" + topo + ".csv")

x = df["Timestamp"]
y1 = df['Uso de memória (MiB)']
y2 = df['% de uso de CPU']

colors = [
    'tab:red',
    'tab:blue'
]

# Plot Line1 (Left Y Axis)
fig, ax = plt.subplots(2, figsize=(16,9), dpi= 200)
ax[0].plot(x, y1, linewidth=4, color=colors[0])
ax[1].plot(x, y2, linewidth=4, color=colors[1])


ax[0].set_title('Uso de memória (Max 300 MiB)', pad=10, fontsize=20)
ax[0].set_ylabel("MiB", labelpad =40, rotation=0, color=colors[0], fontsize=20)
ax[0].tick_params(axis='y', labelcolor=colors[0], labelsize=20 )
ax[0].tick_params(left = True, right = False , labelleft = True , labelbottom = False, bottom = False)


ax[1].set_title('Uso de CPU (Max 400%)', pad=10, fontsize=20)
ax[1].set_ylabel("%", labelpad =40, rotation=0, color=colors[1], fontsize=20)
ax[1].tick_params(axis='y', labelcolor=colors[1], labelsize=20 )
ax[1].tick_params(axis='x', rotation=25, labelsize=12)

ax[1].set_xlabel('Tempo', fontsize=20)

for i in range(2):
    ax[i].axvline(x="19:41:29", linewidth=2.5, color='purple', linestyle=':', label='Execução da Topologia')
    ax[i].axvline(x="19:41:35", linewidth=2.5, color='blue',  linestyle='-.', label='Execução do pingall')
    ax[i].grid(alpha=.4)

plt.subplots_adjust(bottom=0.1, hspace=0.2)
fig.tight_layout()
fig.savefig("plots/" + topo + ".png")
plt.legend()
plt.show()

# %% [markdown]
# # Topologia single 24
# ## Comando mn --topo single24

# %%
from matplotlib import pyplot as plt
import pandas as pd

topo = "single24"
df = pd.read_csv("topo_" + topo + ".csv")

x = df["Timestamp"]
y1 = df['Uso de memória (MiB)']
y2 = df['% de uso de CPU']

colors = [
    'tab:red',
    'tab:blue'
]

# Plot Line1 (Left Y Axis)
fig, ax = plt.subplots(2, figsize=(16,9), dpi= 200)
ax[0].plot(x, y1, linewidth=4, color=colors[0])
ax[1].plot(x, y2, linewidth=4, color=colors[1])


ax[0].set_title('Uso de memória (Max 300 MiB)', pad=10, fontsize=20)
ax[0].set_ylabel("MiB", labelpad =40, rotation=0, color=colors[0], fontsize=20)
ax[0].tick_params(axis='y', labelcolor=colors[0], labelsize=20 )
ax[0].tick_params(left = True, right = False , labelleft = True , labelbottom = False, bottom = False)


ax[1].set_title('Uso de CPU (Max 400%)', pad=10, fontsize=20)
ax[1].set_ylabel("%", labelpad =40, rotation=0, color=colors[1], fontsize=20)
ax[1].tick_params(axis='y', labelcolor=colors[1], labelsize=20 )
ax[1].tick_params(axis='x', rotation=25, labelsize=12)

ax[1].set_xlabel('Tempo', fontsize=20)

for i in range(2):
    ax[i].axvline(x="19:57:17", linewidth=2.5, color='purple', linestyle=':', label='Execução da Topologia')
    ax[i].axvline(x="19:57:27", linewidth=2.5, color='blue',  linestyle='-.', label='Execução do pingall')
    ax[i].grid(alpha=.4)

plt.subplots_adjust(bottom=0.1, hspace=0.2)
fig.tight_layout()
fig.savefig("plots/" + topo + ".png")
plt.legend()
plt.show()

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
 
import pandas as pd
memoryStr = 'Uso de memória (MiB)'
cpuStr = '% de uso de CPU'

single2DF = pd.read_csv("topo_single2.csv")
single8DF = pd.read_csv("topo_single8.csv")
single16DF = pd.read_csv("topo_single16.csv")
single24DF = pd.read_csv("topo_single24.csv")

data = [[
  single2DF[memoryStr], 
  single8DF[memoryStr], 
  single16DF[memoryStr], 
  single24DF[memoryStr]
],
[
  single2DF[cpuStr], 
  single8DF[cpuStr], 
  single16DF[cpuStr], 
  single24DF[cpuStr]
]]
fig, ax = plt.subplots(2, figsize=(16,9), dpi= 200)
fig = plt.figure()
 
for i in range(2):
  bp = ax[i].boxplot(data[i])

for ax_ in ax:
  ax_.set_xlabel('xlabel')
  ax_.set_ylabel('ylabel')
  ax_.set_xticks([1, 2, 3, 4], ['Single 2', 'Single 8', 'Single 16', 'Single 24'])

fig.savefig("plots/singleboxplot.png")
plt.show()
